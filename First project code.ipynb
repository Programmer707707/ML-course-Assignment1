# %%
import pandas as pd
df = pd.read_csv('Desktop/games.csv')

# %%
print(df.head())
# Out:
#                               Game      Revenue Initial release  \
# 0  Honor of Kings / Arena of Valor  14667500000      2015-11-26
# 2                      PUBG Mobile   9000000000      2018-03-19
# 5                       Pokémon Go   7760000000      2016-07-06
# 7                 Fate/Grand Order   6300000000      2015-07-30
# 8         Fantasy Westward Journey   4700000000      2015-03-26
#
#                                Publisher(s)           Genre(s)
# 0                             Tencent Games               MOBA
# 2       Tencent Games / Krafton / VNG Games      Battle royale
# 5             Niantic / The Pokémon Company  Augmented reality
# 7  Aniplex (Sony Music Entertainment Japan)                RPG
# 8                                   NetEase             MMORPG

# %%
df.head()
# Out:
#                               Game      Revenue Initial release  \
# 0  Honor of Kings / Arena of Valor  14667500000      2015-11-26
# 2                      PUBG Mobile   9000000000      2018-03-19
# 5                       Pokémon Go   7760000000      2016-07-06
# 7                 Fate/Grand Order   6300000000      2015-07-30
# 8         Fantasy Westward Journey   4700000000      2015-03-26
#
#                                Publisher(s)           Genre(s)
# 0                             Tencent Games               MOBA
# 2       Tencent Games / Krafton / VNG Games      Battle royale
# 5             Niantic / The Pokémon Company  Augmented reality
# 7  Aniplex (Sony Music Entertainment Japan)                RPG
# 8                                   NetEase             MMORPG

# %%
df.sort_values('Initial release')
# Out:
#                             Game     Revenue Initial release  \
# 67                   8 Ball Pool   400000000      2010-10-15
# 92                    Slotomania   149000000      2011-11-07
# 62                     Minecraft   500000000      2011-11-18
# 3               Puzzle & Dragons  8578340000      2012-02-20
# 47                      Township   922100000      2012-02-24
# ..                           ...         ...             ...
# 61  League of Legends: Wild Rift   505000000      2020-10-27
# 79              Project Makeover   218000000      2020-11-27
# 41       Uma Musume Pretty Derby   990000000      2021-02-24
# 68  Harry Potter: Magic Awakened   358000000      2021-09-09
# 71                     Lineage W   302985000      2021-11-04
#
#                    Publisher(s)             Genre(s)
# 67                     Miniclip        Sports (pool)
# 92                     Playtika    Simulation (Slot)
# 62               Mojang Studios   Sandbox / Survival
# 3   GungHo Online Entertainment         RPG / Puzzle
# 47                      Playrix     Simulation (CMS)
# ..                          ...                  ...
# 61         Riot Games (Tencent)                 MOBA
# 79              Bubblegum Games  Puzzle / Decoration
# 41                      Cygames  Simulation / Social
# 68      NetEase / Portkey Games                  RPG
# 71                       NCsoft               MMORPG
#
# [104 rows x 5 columns]

# %%
df.sort_values('Revenue', ascending=False)
# Out:
#                                 Game      Revenue Initial release  \
# 0    Honor of Kings / Arena of Valor  14667500000      2015-11-26
# 1                     Monster Strike  10000000000      2013-08-08
# 2                        PUBG Mobile   9000000000      2018-03-19
# 3                   Puzzle & Dragons   8578340000      2012-02-20
# 4                     Clash of Clans   8000000000      2012-08-02
# ..                               ...          ...             ...
# 99              Yahtzee With Buddies    113000000      2017-11-01
# 100                Dragon Quest Tact    111990000      2020-07-16
# 101                  Fallout Shelter    100000000      2015-06-14
# 102                       Mafia City    100000000      2017-07-25
# 103             Madden NFL Overdrive    100000000      2018-08-15
#
#                             Publisher(s)                    Genre(s)
# 0                          Tencent Games                        MOBA
# 1                                   Mixi     Puzzle / RPG / Strategy
# 2    Tencent Games / Krafton / VNG Games               Battle royale
# 3            GungHo Online Entertainment                RPG / Puzzle
# 4                    Supercell (Tencent)                    Strategy
# ..                                   ...                         ...
# 99                               Scopely                     Yahtzee
# 100                          Square Enix                Tactical RPG
# 101                   Bethesda Softworks            Simulation (CMS)
# 102                          Yotta Games                         RPG
# 103          EA Sports (Electronic Arts)  Sports (American football)
#
# [104 rows x 5 columns]

# %%
new_df = df.loc[(df['Revenue']>3000000000)&(df['Initial release'] > '2015')]

# %%
new_df.reset_index()
# Out:
#    index                             Game      Revenue Initial release  \
# 0      0  Honor of Kings / Arena of Valor  14667500000      2015-11-26
# 1      2                      PUBG Mobile   9000000000      2018-03-19
# 2      5                       Pokémon Go   7760000000      2016-07-06
# 3      7                 Fate/Grand Order   6300000000      2015-07-30
# 4      8         Fantasy Westward Journey   4700000000      2015-03-26
# 5      9                 Garena Free Fire   4330000000      2017-12-04
# 6     11                   Genshin Impact   3567000000      2020-09-28
# 7     12                        Lineage M   3578000000      2017-06-21
# 8     13     Dragon Ball Z: Dokkan Battle   3500000000      2015-01-30
# 9     14                      Coin Master   3008000000      2018-03-19
#
#                                Publisher(s)           Genre(s)
# 0                             Tencent Games               MOBA
# 1       Tencent Games / Krafton / VNG Games      Battle royale
# 2             Niantic / The Pokémon Company  Augmented reality
# 3  Aniplex (Sony Music Entertainment Japan)                RPG
# 4                                   NetEase             MMORPG
# 5                                    Garena      Battle royale
# 6                                    miHoYo         Action RPG
# 7                                    NCsoft             MMORPG
# 8                Bandai Namco Entertainment       RPG / Puzzle
# 9                               Moon Active    Casual / Casino

# %%
import matplotlib as pt

# %%
new_df.plot(kind='bar', color='green', title='Top 10 Mobile Games with revenue > 3 Billion ', xlabel='Games', ylabel='Revenue in billions')
# Out:
# <AxesSubplot:title={'center':'Top 10 Mobile Games with revenue > 3 Billion '}, xlabel='Games', ylabel='Revenue in billions'>

# %%
print(new_df)
# Out:
#                                Game      Revenue Initial release  \
# 0   Honor of Kings / Arena of Valor  14667500000      2015-11-26
# 2                       PUBG Mobile   9000000000      2018-03-19
# 5                        Pokémon Go   7760000000      2016-07-06
# 7                  Fate/Grand Order   6300000000      2015-07-30
# 8          Fantasy Westward Journey   4700000000      2015-03-26
# 9                  Garena Free Fire   4330000000      2017-12-04
# 11                   Genshin Impact   3567000000      2020-09-28
# 12                        Lineage M   3578000000      2017-06-21
# 13     Dragon Ball Z: Dokkan Battle   3500000000      2015-01-30
# 14                      Coin Master   3008000000      2018-03-19
#
#                                 Publisher(s)           Genre(s)
# 0                              Tencent Games               MOBA
# 2        Tencent Games / Krafton / VNG Games      Battle royale
# 5              Niantic / The Pokémon Company  Augmented reality
# 7   Aniplex (Sony Music Entertainment Japan)                RPG
# 8                                    NetEase             MMORPG
# 9                                     Garena      Battle royale
# 11                                    miHoYo         Action RPG
# 12                                    NCsoft             MMORPG
# 13                Bandai Namco Entertainment       RPG / Puzzle
# 14                               Moon Active    Casual / Casino

# %%
df.head()
# Out:
#                               Game      Revenue Initial release  \
# 0  Honor of Kings / Arena of Valor  14667500000      2015-11-26
# 2                      PUBG Mobile   9000000000      2018-03-19
# 5                       Pokémon Go   7760000000      2016-07-06
# 7                 Fate/Grand Order   6300000000      2015-07-30
# 8         Fantasy Westward Journey   4700000000      2015-03-26
#
#                                Publisher(s)           Genre(s)
# 0                             Tencent Games               MOBA
# 2       Tencent Games / Krafton / VNG Games      Battle royale
# 5             Niantic / The Pokémon Company  Augmented reality
# 7  Aniplex (Sony Music Entertainment Japan)                RPG
# 8                                   NetEase             MMORPG

# %%
import seaborn as sns
sns.barplot(data=new_df,x='Game', y='Revenue')
# Out:
# <AxesSubplot:xlabel='Game', ylabel='Revenue'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
plt.xticks(rotation=65)
sns.barplot(x=new_df['Game'], y=new_df['Revenue'])
# Out:
# <AxesSubplot:xlabel='Game', ylabel='Revenue'>
